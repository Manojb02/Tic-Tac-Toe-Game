# %%
from IPython.display import clear_output
board = ["#","-","-","-","-","-","-","-","-","-"]
def display_board():
    clear_output()
    
    print (board[1],"|",board[2],"|",board[3])
    print (board[4],"|",board[5],"|",board[6])
    print (board[7],"|",board[8],"|",board[9])

def ask():
    let = True
    global player1
    global player2
    while let:
        player1 = input("Player1 : Please choose from X and O : ").upper()
        if player1 != "X" and player1 != "O":
            continue
        if player1=="X" or player1=="O":
            if player1 =="X":
                player2='O'
                print("player1: {}".format(player1))
                
                print("player2 :O")
                break
            else:
                print("player1: {}".format(player1))
                player2= 'X'
                
                print("player2 :X")
                break
def play(): 

    display_board()
    ask()
    check = True
    number = [1,2,3,4,5,6,7,8,9]
    occupied = ['x']
  
    global player_1
    global player_2
    while check:

        player_1 = int(input("Player_1 turn : please choose number in between 1 to 9 :"))
        if player_1 not in number or player_1  in occupied:

            print ("Number not in between 1 to 9 !!!  or already taken Try again")
            continue

        if player_1 in number and player_1 not in occupied:
            board[player_1]=player1
            occupied.append(player_1)
            display_board()
            if (board[1]==board[2]==board[3]!= "-") or (board[4]==board[5]==board[6]!= "-"):
                print("Winner : Player 1 : Congrats" ) 
                check = False
                break
            if ('-' not in board):
                print("match draw")
                break
    
        player_2 = int(input("Player_2 turn : please choose number in between 1 to 9 :"))
        while player_2 not in number or player_2  in occupied:
            

            print ("Number not in between 1 to 9 !!!  or already taken Try again")
            player_2 = int(input("Player_2 turn : please choose number in between 1 to 9 :"))
            continue
        if player_2 in number and player_2 not in occupied:
           
            board[player_2]= player2
            display_board()
            occupied.append(player_2)
            if (board[1]==board[2]==board[3]!= "-") or (board[4]==board[5]==board[6]!= "-"):
                print("Winner : Player 2 : Congrats" )
                check = False
                break
            if ('-' not in board):
                print("match draw")


                
play()
# Out:
# - | - | -
# - | - | -
# - | - | -
